# %%
import numpy as np
import pandas as pd

# %%
cd
# Out:
# C:\Users\hp

# %%
cd desktop\Python
# Out:
# C:\Users\hp\desktop\Python

# %%
data = pd.read_csv('HousePrices.csv')

# %%
data.head()
# Out:
#    Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type Alley  \
# 0   1          60         RL         65.0     8450      Pave   NaN
# 1   2          20         RL         80.0     9600      Pave   NaN
# 2   3          60         RL         68.0    11250      Pave   NaN
# 3   4          70         RL         60.0     9550      Pave   NaN
# 4   5          60         RL         84.0    14260      Pave   NaN
#
#   Property_Shape LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature  \
# 0            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 1            Reg         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 2            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 3            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
# 4            IR1         Lvl    AllPub  ...        0    NaN   NaN         NaN
#
#   MiscVal MoSold YrSold  SaleType  SaleCondition  Property_Sale_Price
# 0       0      2   2008        WD         Normal               208500
# 1       0      5   2007        WD         Normal               181500
# 2       0      9   2008        WD         Normal               223500
# 3       0      2   2006        WD        Abnorml               140000
# 4       0     12   2008        WD         Normal               250000
#
# [5 rows x 81 columns]

# %%
data.drop('Alley',axis = 1,inplace = True)
data.drop('PoolQC',axis = 1,inplace = True)

# %%
data['LotFrontage'].fillna(0,inplace = True)
data['MasVnrType'].fillna('None',inplace = True)
data['MasVnrArea'].fillna(0,inplace = True)
data['BsmtQual'].fillna('NA',inplace= True)
data['BsmtCond'].fillna('NA',inplace= True)
data['BsmtExposure'].fillna('No',inplace = True)
data['BsmtFinType1'].fillna('No',inplace = True)
data['BsmtFinType2'].fillna('No',inplace = True)
data['Electrical'].fillna('No',inplace = True)
data['FireplaceQu'].fillna('No',inplace = True)
data['GarageType'].fillna('No',inplace = True)
data['GarageYrBlt'].fillna('0',inplace = True)
data['GarageFinish'].fillna('No',inplace = True)
data['GarageQual'].fillna('No',inplace = True)
data['GarageCond'].fillna('No',inplace = True)
data.drop('Fence',axis = 1,inplace = True)

# %%
data.drop('MiscFeature',axis = 1,inplace=True)

# %%
data.columns[data.isna().any()].tolist()# no we don't have any nan columns
# Out:
# []

# %%
data
# Out:
#        Id  Dwell_Type Zone_Class  LotFrontage  LotArea Road_Type  \
# 0       1          60         RL         65.0     8450      Pave
# 1       2          20         RL         80.0     9600      Pave
# 2       3          60         RL         68.0    11250      Pave
# 3       4          70         RL         60.0     9550      Pave
# 4       5          60         RL         84.0    14260      Pave
# ...   ...         ...        ...          ...      ...       ...
# 2068  942          60         RL          0.0     8755      Pave
# 2069  943          90         RL         63.0     7711      Pave
# 2070  944          90         RL        313.0    25000      Pave
# 2071  945          20         RL         52.0    14375      Pave
# 2072  946          50         RM         98.0     8820      Pave
#
#      Property_Shape LandContour Utilities LotConfig  ... EnclosedPorch  \
# 0               Reg         Lvl    AllPub    Inside  ...             0
# 1               Reg         Lvl    AllPub       FR2  ...             0
# 2               IR1         Lvl    AllPub    Inside  ...             0
# 3               IR1         Lvl    AllPub    Corner  ...           272
# 4               IR1         Lvl    AllPub       FR2  ...             0
# ...             ...         ...       ...       ...  ...           ...
# 2068            IR1         Lvl    AllPub       FR2  ...             0
# 2069            IR1         Lvl    AllPub    Inside  ...             0
# 2070            Reg         Low    AllPub    Inside  ...             0
# 2071            IR1         Lvl    NoSeWa   CulDSac  ...             0
# 2072            Reg         Lvl    AllPub    Corner  ...           244
#
#      3SsnPorch ScreenPorch PoolArea MiscVal MoSold  YrSold  SaleType  \
# 0            0           0        0       0      2    2008        WD
# 1            0           0        0       0      5    2007        WD
# 2            0           0        0       0      9    2008        WD
# 3            0           0        0       0      2    2006        WD
# 4            0           0        0       0     12    2008        WD
# ...        ...         ...      ...     ...    ...     ...       ...
# 2068       168           0        0       0      6    2009        WD
# 2069         0           0        0       0      8    2007       Oth
# 2070         0           0        0       0      6    2007        WD
# 2071         0         233        0       0      1    2009       COD
# 2072         0           0        0       0      9    2009        WD
#
#       SaleCondition  Property_Sale_Price
# 0            Normal               208500
# 1            Normal               181500
# 2            Normal               223500
# 3           Abnorml               140000
# 4            Normal               250000
# ...             ...                  ...
# 2068         Normal               214000
# 2069        Abnorml               150000
# 2070         Normal               143000
# 2071        Abnorml               137500
# 2072         Normal               124900
#
# [2073 rows x 77 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

data['Zone_Class'] = le.fit_transform(data['Zone_Class'])

data['Road_Type'] = le.fit_transform(data['Road_Type'])

data['Property_Shape'] = le.fit_transform(data['Property_Shape'])

data['LandContour'] = le.fit_transform(data['LandContour'])

data['Utilities'] = le.fit_transform(data['Utilities'])

data['LotConfig'] = le.fit_transform(data['LotConfig'])

data['LandSlope'] = le.fit_transform(data['LandSlope'])

data['Neighborhood'] = le.fit_transform(data['Neighborhood'])

data['Condition1'] = le.fit_transform(data['Condition1'])

data['Condition2'] = le.fit_transform(data['Condition2'])

data['Dwelling_Type'] = le.fit_transform(data['Dwelling_Type'])

data['HouseStyle'] = le.fit_transform(data['HouseStyle'])

data['RoofStyle'] = le.fit_transform(data['RoofStyle'])

data['RoofMatl'] = le.fit_transform(data['RoofMatl'])

data['Exterior1st'] = le.fit_transform(data['Exterior1st'])

data['Exterior2nd'] = le.fit_transform(data['Exterior2nd'])

data['ExterQual'] = le.fit_transform(data['ExterQual'])

data['ExterCond'] = le.fit_transform(data['ExterCond'])

data['Foundation'] = le.fit_transform(data['Foundation'])

data['Heating'] = le.fit_transform(data['Heating'])

data['HeatingQC'] = le.fit_transform(data['HeatingQC'])

data['CentralAir'] = le.fit_transform(data['CentralAir'])

data['KitchenQual'] = le.fit_transform(data['KitchenQual'])

data['Functional'] = le.fit_transform(data['Functional'])

data['PavedDrive'] = le.fit_transform(data['PavedDrive'])

data['SaleType'] = le.fit_transform(data['SaleType'])

data['SaleCondition'] = le.fit_transform(data['SaleCondition'])

data['GarageQual'] = le.fit_transform(data['GarageQual'])

data['MasVnrType'] = le.fit_transform(data['MasVnrType'])

data['BsmtQual'] = le.fit_transform(data['BsmtQual'])

data['BsmtCond'] = le.fit_transform(data['BsmtCond'])

data['BsmtExposure'] = le.fit_transform(data['BsmtExposure'])

data['BsmtFinType1'] = le.fit_transform(data['BsmtFinType1'])

data['BsmtFinType2'] = le.fit_transform(data['BsmtFinType2'])

data['Electrical'] = le.fit_transform(data['Electrical'])

data['FireplaceQu'] = le.fit_transform(data['FireplaceQu'])

data['GarageType'] = le.fit_transform(data['GarageType'])

data['GarageFinish'] = le.fit_transform(data['GarageFinish'])

data['GarageCond'] = le.fit_transform(data['GarageCond'])

# %%
data['GarageYrBlt'] = pd.to_numeric(data['GarageYrBlt'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2073 entries, 0 to 2072
# Data columns (total 77 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   2073 non-null   int64
#  1   Dwell_Type           2073 non-null   int64
#  2   Zone_Class           2073 non-null   int64
#  3   LotFrontage          2073 non-null   float64
#  4   LotArea              2073 non-null   int64
#  5   Road_Type            2073 non-null   int64
#  6   Property_Shape       2073 non-null   int64
#  7   LandContour          2073 non-null   int64
#  8   Utilities            2073 non-null   int64
#  9   LotConfig            2073 non-null   int64
#  10  LandSlope            2073 non-null   int64
#  11  Neighborhood         2073 non-null   int64
#  12  Condition1           2073 non-null   int64
#  13  Condition2           2073 non-null   int64
#  14  Dwelling_Type        2073 non-null   int64
#  15  HouseStyle           2073 non-null   int64
#  16  OverallQual          2073 non-null   int64
#  17  OverallCond          2073 non-null   int64
#  18  YearBuilt            2073 non-null   int64
#  19  YearRemodAdd         2073 non-null   int64
#  20  RoofStyle            2073 non-null   int64
#  21  RoofMatl             2073 non-null   int64
#  22  Exterior1st          2073 non-null   int64
#  23  Exterior2nd          2073 non-null   int64
#  24  MasVnrType           2073 non-null   int64
#  25  MasVnrArea           2073 non-null   float64
#  26  ExterQual            2073 non-null   int64
#  27  ExterCond            2073 non-null   int64
#  28  Foundation           2073 non-null   int64
#  29  BsmtQual             2073 non-null   int64
#  30  BsmtCond             2073 non-null   int64
#  31  BsmtExposure         2073 non-null   int64
#  32  BsmtFinType1         2073 non-null   int64
#  33  BsmtFinSF1           2073 non-null   int64
#  34  BsmtFinType2         2073 non-null   int64
#  35  BsmtFinSF2           2073 non-null   int64
#  36  BsmtUnfSF            2073 non-null   int64
#  37  TotalBsmtSF          2073 non-null   int64
#  38  Heating              2073 non-null   int64
#  39  HeatingQC            2073 non-null   int64
#  40  CentralAir           2073 non-null   int64
#  41  Electrical           2073 non-null   int64
#  42  1stFlrSF             2073 non-null   int64
#  43  2ndFlrSF             2073 non-null   int64
#  44  LowQualFinSF         2073 non-null   int64
#  45  GrLivArea            2073 non-null   int64
#  46  BsmtFullBath         2073 non-null   int64
#  47  BsmtHalfBath         2073 non-null   int64
#  48  FullBath             2073 non-null   int64
#  49  HalfBath             2073 non-null   int64
#  50  BedroomAbvGr         2073 non-null   int64
#  51  KitchenAbvGr         2073 non-null   int64
#  52  KitchenQual          2073 non-null   int64
#  53  TotRmsAbvGrd         2073 non-null   int64
#  54  Functional           2073 non-null   int64
#  55  Fireplaces           2073 non-null   int64
#  56  FireplaceQu          2073 non-null   int64
#  57  GarageType           2073 non-null   int64
BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','LowQualFinSF'],axis=1,inplace = True)
# as these have infine Vif due to Zero values... so we drop them... as it is not good for our training

# %%
data.shape
# Out:
# (2073, 70)

# %%
X = data.iloc[:,:69]

# %%
y= data.iloc[:,69:]

# %%
X
# Out:
#        Id  Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  \
# 0       1          60           3         65.0     8450          1
# 1       2          20           3         80.0     9600          1
# 2       3          60           3         68.0    11250          1
# 3       4          70           3         60.0     9550          1
# 4       5          60           3         84.0    14260          1
# ...   ...         ...         ...          ...      ...        ...
# 2068  942          60           3          0.0     8755          1
# 2069  943          90           3         63.0     7711          1
# 2070  944          90           3        313.0    25000          1
# 2071  945          20           3         52.0    14375          1
# 2072  946          50           4         98.0     8820          1
#
#       Property_Shape  LandContour  Utilities  LotConfig  ...  OpenPorchSF  \
# 0                  3            3          0          4  ...           61
# 1                  3            3          0          2  ...            0
# 2                  0            3          0          4  ...           42
# 3                  0            3          0          0  ...           35
# 4                  0            3          0          2  ...           84
# ...              ...          ...        ...        ...  ...          ...
# 2068               0            3          0          2  ...            0
# 2069               0            3          0          4  ...            0
# 2070               3            2          0          4  ...            0
# 2071               0            3          1          1  ...          118
# 2072               3            3          0          0  ...            0
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# 0                 0          0            0         0        0       2
# 1                 0          0            0         0        0       5
# 2                 0          0            0         0        0       9
# 3               272          0            0         0        0       2
# 4                 0          0            0         0        0      12
# ...             ...        ...          ...       ...      ...     ...
# 2068              0        168            0         0        0       6
# 2069              0          0            0         0        0       8
# 2070              0          0            0         0        0       6
# 2071              0          0          233         0        0       1
# 2072            244          0            0         0        0       9
#
#       YrSold  SaleType  SaleCondition
# 0       2008         8              4
# 1       2007         8              4
# 2       2008         8              4
# 3       2006         8              0
# 4       2008         8              4
# ...      ...       ...            ...
# 2068    2009         8              4
# 2069    2007         7              0
# 2070    2007         8              4
# 2071    2009         0              0
# 2072    2009         8              4
#
# [2073 rows x 69 columns]

# %%
print(y)
# Out:
#       Property_Sale_Price
# 0                  208500
# 1                  181500
# 2                  223500
# 3                  140000
# 4                  250000
# ...                   ...
# 2068               214000
# 2069               150000
# 2070               143000
# 2071               137500
# 2072               124900
#
# [2073 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y, test_size = 0.2, random_state = 123) #give any name to random_state

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (1658, 69)
# (1658, 1)
# (415, 69)
# (415, 1)

# %%
from sklearn import linear_model #Parametric Model

# %%
regr = linear_model.LinearRegression()
regr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# The coefficients
print('Coefficients', regr.coef_)
print('Intercept',regr.intercept_)
# Out:
# Coefficients [[-2.23755677e+00 -6.20036247e+00 -1.68905111e+03 -9.64557592e+00
#    2.40104009e-01  5.26553152e+04 -1.39609186e+03  2.86433422e+03
#   -4.68238425e+04  7.78720670e+02  1.00648762e+04  5.26130207e+02
#   -5.23215578e+01 -5.29571679e+03 -4.29236618e+03 -1.67603016e+03
#    1.94746201e+03  2.84389455e+03  6.78563865e+01  4.92077527e+01
#    3.32925847e+03  3.63279324e+03 -1.68635390e+03  9.38862603e+02
#    4.05361024e+03  3.43619656e+01 -1.17794844e+04  1.14778484e+03
#    1.33232370e+03 -4.99261609e+03  1.54479064e+03 -4.51983111e+03
#   -9.00356330e+02  1.21351967e+03 -3.68461278e+03 -1.07513885e+03
#    9.22089201e+03  4.34488714e+02  4.91496779e+01  1.08141023e+04
#    3.13889428e+03  6.82213090e+03  1.58168894e+01 -4.13093700e+03
#   -2.14305122e+04 -1.10385101e+04  2.61951688e+03  4.84486931e+03
#    6.49297673e+03 -1.57600301e+03 -6.74199956e+02 -9.72691563e+00
#   -1.89148486e+03  1.46643185e+04  1.15753357e+01 -9.70745033e+02
#    2.08574701e+03  3.62412411e+03  2.74350214e+01  4.85735263e+00
#    6.49295142e+00  2.19923921e+01  5.37305922e+01 -1.49481320e+00
#    4.27274292e-01  1.31621671e+02 -7.44663081e+02 -1.00982896e+03
#    3.19185036e+03]]
# Intercept [1289143.03770731]

# %%
X.columns
# Out:
# Index(['Id', 'Dwell_Type', 'Zone_Class', 'LotFrontage', 'LotArea', 'Road_Type',
#        'Property_Shape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'Dwelling_Type',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', 'GrLivArea', 'BsmtFullBath',
#        'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr',
#        'KitchenQual', 'TotRmsAbvGrd', 'Functional', 'Fireplaces',
#        'FireplaceQu', 'GarageType', 'GarageYrBlt', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
#        'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
#        'SaleCondition'],
#       dtype='object')

# %%
X_test.head()
# Out:
#         Id  Dwell_Type  Zone_Class  LotFrontage  LotArea  Road_Type  \
# 1935   981          85           3          0.0    12122          1
# 715    716          20           3         78.0    10140          1
# 1392  1393          85           3         68.0     7838          1
# 452    453          60           3          0.0     9303          1
# 1270  1271          40           3          0.0    23595          1
#
#       Property_Shape  LandContour  Utilities  LotConfig  ...  OpenPorchSF  \
# 1935               0            3          0          0  ...           76
# 715                3            3          0          4  ...            0
# 1392               3            3          0          4  ...          144
# 452                0            3          0          0  ...          122
# 1270               3            2          0          4  ...            0
#
#       EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  MiscVal  MoSold  \
# 1935              0          0            0         0        0       7
# 715               0          0            0         0        0       8
# 1392              0          0            0         0        0      12
# 452               0          0            0         0        0       7
# 1270              0          0            0         0        0       4
#
#       YrSold  SaleType  SaleCondition
# 1935    2008         8              4
# 715     2009         8              4
# 1392    2006         8              4
# 452     2007         8              4
# 1270    2010         8              4
#
# [5 rows x 69 columns]

# %%
y_test.head()
# Out:
#       Property_Sale_Price
# 1935               178400
# 715                165000
# 1392               123000
# 452                204000
# 1270               260000

# %%
y_pred = regr.predict(X_test)

# %%
y_pred
# Out:
# array([[229422.46034009],
#        [165005.04786912],
#        [124796.77511408],
#        [231041.24501025],
#        [275539.82142608],
#        [112623.04413482],
#        [249126.30069894],
#        [236172.04406423],
#        [101952.53194729],
#        [259945.58223715],
#        [246251.14748308],
#        [287615.45211663],
#        [166928.78312455],
#        [131869.95326442],
#        [193040.27457103],
#        [249766.55851579],
#        [349617.23259002],
#        [147355.50252561],
#        [222692.57055916],
#        [171084.61875808],
#        [133556.51378232],
#        [221202.30554367],
#        [283649.12633418],
#        [257817.56599676],
#        [265878.62678627],
#        [223264.08090291],
#        [180415.1017299 ],
#        [ 95185.65368764],
#        [293168.63513389],
#        [107579.98098564],
#        [107508.77112065],
#        [195911.96707538],
#        [134853.01798905],
#        [108592.82757923],
#        [113777.89695459],
#        [155309.81585207],
#        [133981.19231   ],
#        [130529.28587705],
#        [209933.09836747],
#        [134175.58856709],
#        [281271.30831938],
#        [103927.18134317],
#        [125168.11917844],
#        [223485.33359192],
#        [188128.00164777],
#        [213603.07058453],
#        [242873.92514856],
#        [216015.48090972],
#        [185271.88768901],
#        [262081.11151287],
#        [ 84209.40393208],
#        [163098.8261475 ],
#        [231327.05894906],
#        [184370.55415147],
#        [242798.74289058],
#        [255909.24615904],
#        [182031.87901709],
#        [164148.99976081],
#        [168849.95244085],
#        [ 95522.07611971],
#        [365308.87371535],
#        [312247.81665326],
#        [130864.50565608],
#        [389388.90403627],
#        [266752.56656964],
#        [113071.17664087],
#        [ 76248.84449004],
#        [158536.158818  ],
#        [232580.17069915],
#        [137423.83814824],
#        [131233.88178168],
#        [122801.2265131 ],
#        [140069.42632626],
#        [200426.19938081],
#        [335393.73788342],
#        [252473.96698564],
#        [107353.38681717],
#        [121468.90698394],
#        [275296.79681985],
#        [ 57698.00661606],
#        [310442.33598099],
#        [335786.73128563],
#        [160912.41801715],
#        [ 77268.14943163],
#        [ 79067.57498274],
#        [180120.18073704],
#        [130139.25468406],
#        [128089.38724715],
#        [307538.32211901],
#        [120139.01776008],
#        [216213.5677204 ],
#        [247830.23123169],
#        [149550.38179709],
#        [148271.60539763],
#        [ 89323.66320848],
#        [289570.81917928],
#        [149550.38179709],
#        [103599.31543785],
#        [131421.84032868],
#        [227725.12371863],
#        [264753.46148138],
#        [229593.5017464 ],
#        [125430.28160273],
#        [248007.00137312],
#        [310510.6034403 ],
#        [187296.29655907],
#        [141415.87866281],
#        [277525.22917307],
#        [176198.33071954],
#        [102318.94226873],
#        [157676.93356681],
#        [267129.83813629],
#        [225094.34512505],
#        [175088.34149484],
#        [202191.13810432],
#        [205490.08780617],
#        [131095.34955496],
#        [118766.74562076],
#        [228523.61888477],
#        [138277.60591165],
#        [140073.08355898],
#        [231711.77842376],
#        [ 75845.93703857],
#        [321640.30959654],
#        [212840.99678372],
#        [123020.4170258 ],
#        [143066.43773964],
#        [209377.84114775],
#        [173819.81813977],
#        [192836.70165602],
#        [109569.02736475],
#        [154735.34533243],
#        [243650.70432849],
#        [ 93278.52929577],
#        [120641.92328025],
#        [211133.06646813],
#        [213309.05457206],
#        [209358.24878553],
#        [148894.7455652 ],
#        [296607.66413946],
#        [ 86940.58643301],
#        [127332.31791553],
#        [105972.60595435],
#        [172501.20861498],
#        [348977.71641538],
#        [ 83827.64561059],
#        [274732.86128666],
#        [201022.11651099],
#        [212120.86633294],
#        [136840.21006544],
#        [154771.99225161],
#        [145450.32615603],
#        [155705.66830759],
#        [282993.80988009]])

# %%
#Mean Error Value
#Mean Squared Error 
#Evaluation 
from sklearn.metrics import mean_squared_error, r2_score
print(mean_squared_error(y_test, y_pred)) #MSE
# Out:
# 1030960647.2575501

# %%
import matplotlib.pyplot as plt
# Plot outputs
plt.scatter(y_test, y_pred,  color='black')

# %%
print(r2_score(y_test, y_pred))
# Out:
# 0.85896059241765

# %%
#Training Accuracy
y_pred = regr.predict(X_train)

# %%
y_pred
# Out:
# array([[274300.31698289],
#        [190712.98269424],
#        [289951.85563253],
#        ...,
#        [132460.90236319],
#        [ 90402.25080781],
#        [233980.35483948]])

# %%
print(r2_score(y_train, y_pred))
# Out:
# 0.8378594357994817

# %%
y_test.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Property_Sale_Price'}>]],
#       dtype=object)

# %%
y_train.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Property_Sale_Price'}>]],
#       dtype=object)
